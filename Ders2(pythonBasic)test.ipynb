# %% [markdown]
# 1) Verilən ədədlərin hasilini tapan və göstərilən outputu qaytaran proqram yazın
#
# Input: number1 = 20
# 	number2 = 30
#
# Output:
# The result is 600

# %%
number1=20
number2=30
print("the result is {}".format(number1*number2))
# Out:
# the result is 600

# %% [markdown]
# 2) Verilmis variabl-in type-ını göstərən proqram yazın.
# İnput: a = 5
# Outpunt: int

# %%
a=5
type(a)
# Out:
# int

# %% [markdown]
# 3) Aşağıdakı kimi output qaytaran proqram yazın.
#
# İnput: totalMoney = 1000
# 	quantity = 3
# 	price = 450
# Output:
#  	I have 1000 dollars so I can buy 3 football for 450.00 dollars.

# %%
totalMoney=1000
quantity=3
price = 450
print("I have {} dollar so I can buy {} football for {}".format(totalMoney,quantity,price))
# Out:
# I have  1000

# %% [markdown]
# 4) Verilmis stringin ilk 3 elementini çap edən proqram yazın.
# Input: var = 'Hello world!'
# Output: 'Hel'

# %%
var='Hello world!'
print(var[0:3])
# Out:
# Hel

# %% [markdown]
# 5) İki ədədin cəmini tapan funksiya yazın.
# Input: num1 = 2, num2 = 4
# Output: func(num1,num2) - > 2 + 4 -> 6

# %%
def iki_ededin_cemi(num1,num2):
  print(num1+num2)

# %%
num1=2
num2=4
iki_ededin_cemi(num1,num2)
# Out:
# 6

# %% [markdown]
# 6) Listdəki cüt ədədləri tapan proqram yazın.
# İnput: [1,2,3,4,5]
# Output: [2,4]

# %%
listim=[1,2,3,4,5]
for a in listim:
  if a%2==0:
    print(a)
# Out:
# 2
# 4
