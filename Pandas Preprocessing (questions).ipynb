# %% [markdown]
# To answer the questions, please refer to the name of the dataset at the end of each question.

# %%
# Question 1
# Dummify the categorical column of the Iris dataset. For instance,
# Iris-versicolor   -- 0
# Iris-virginica    -- 1
# Iris-setosa       -- 2 (Iris data)

# %%
# Question 2
# Write a function to equalize the values that are more than 3 standard deviations away
# from the average to the sum of mean and 3 standard deviations. Please, do this 
# for every numerical column (Iris data)

# %%
# Question 3
# Import the wine dataset and delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns
# and assign these names below what is remaining:
# alcohol
# malic_acid
# alcalinity_of_ash
# magnesium
# flavanoids
# proanthocyanins
# hue (Wine data)

# %%
# Question 4
# Create an array of 10 random numbers up until 10 and use 
# those random numbers you as an index and assign null value to every columns' cells (Wine data)

# %%
# Question 5
# After reading and renaming the dataset's columns, set the rows to null if mean of numerical columns' rows 
# is smaller than 3.5 and keep the rest as the same (Iris data)

# %%
# Question 6
# Delete the rows that have nulls (Iris data)

# %%
# Question 7
# Reset the index so it begins with 0 again (Iris data)

# %%
# Question 8
# Read the wine dataset then check all the data types of numerical columns and transform them into appropriate 
# integer and/or float values to reduce memory space (wine data)

# %%
# Question 9
# Read this file and transform the given text to lowercase then capitalize every word using a 
# lambda function (indian data)

# %%
# Question 10
# Read this file and make a transformation on each word so that wherever there's a single vowel
# in a word it should be doubled. The rest must remain the same (gujarati data)
