# %% [markdown]
# 1) Verilən stringi tərsinə çevirən proqram yazın.
#
# Input : str = "my name is Python"
# output : str= "Python is name my"
#
# 2) Verilən dictionary-ni a) key     -yə görə sort edən proqram yazın.
# 			 b) value
# İnput: {2: 56,
# 	1: 2,
# 	5: 12,
# 	4: 24,
# 	6: 18,
# 	3: 323}
#
# Task a output: 1, 2, 3, 4, 5, 6
# Task b output: 2, 12, 18, 24, 56, 323
#
#
# 3) Listin birinci və sonuncu elementlərinin yerini dəyişən proqram yazın.
# Input : [1, 2, 3]
# Output : [3, 2, 1]
#
#
# 4) Verilmiş listin elementlərinin ədədi ortasini tapan funksiya yazın. (mean, len və sum funksiyalarini istifadə etmədən)
# İnput: [1,2,3,4]
# Output: 2.5
#
# 5) Verilən dictionary-də max və min value-ları tapan python proqramı yazın.
#
#
# 6) Daxil olunan elementin qüvvətini tapan proqram yazın. (Rekursiyadan istifadə edərək).
#
# İnput: N = 5
#        P = 2
#
# Output: power(N, P) -> 25
#
#
# 7) Verilmiş ədədə qədər listin elementlərini birləşdirən proqram yazın.
# İnput : ['p', 'q'] , n = 5
# Output : ['p1', 'q1', 'p2', 'q2', 'p3', 'q3', 'p4', 'q4', 'p5', 'q5']
#
#
# 8) Nested loop-lardan istifadə edərək aşağıdakı fiquru qurun.
#
# 	*
# 	* *
# 	* * *
# 	* * * *
# 	* * * * *
# 	* * * *
# 	* * *
# 	* *
# 	*

# %%
#1) 
s =' '.join(reversed("my name is Python".split(' ')))
print(s)
# Out:
# Python is name my

# %%
#2)
dict1={2: 56, 1: 2, 5: 12, 4: 24, 6: 18, 3: 323}
print(sorted(dict1.keys()))
print(sorted(dict1.values()))
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, 12, 18, 24, 56, 323]

# %%
#3)
list1=[1,2,3]
list1.reverse()
print(list1)
# Out:
# [3, 2, 1]

# %%
#4)
nums = [9,2,30,4]
s = 0; c = 0; 

for num in nums: s += num; c += 1;

s/c
# Out:
# 11.25

# %%
#5)
dictionary=[1,5,85,14]
max=nums[0]
min=nums[0]
for num in dictionary:
      if max<num:
        max=num
      elif min>num:
        min=num
     

print(max,min)
# Out:
# 85 1

# %%
#6)
P=2
N=5
res=1
while True:
    res*=N
    P-=1
    if P == False:
      break
print(res)
# Out:
# 25
